# %% [markdown]
# # 10 · Regenerate the schema documentation
#
# > **Run order.** This notebook is step - of the pipeline. Earlier steps must
# > have run at least once. See [`notebooks/README.md`](README.md).
# >
# > All reusable logic lives in `src/analyst/` — the package is unit-tested and
# > type-checked, and these notebooks orchestrate it and show the results.
#
#
# `docs/data/schema.md` is **generated**, never hand-written — hand-written schema
# docs are wrong within a week. This reads live SQLAlchemy metadata plus real row
# counts and rewrites the reference.
#
# **Run this after any model change**, as the maintenance policy in
# [`docs/README.md`](../docs/README.md) requires.

# %%
from analyst.schema_docs import generate

# The generator lives in the library so a notebook and CI call the same
# code, and it anchors its own output path to the repo root.
out = generate()
print(f"regenerated {out.name}  ({out.stat().st_size:,} bytes)")
# Out:
# regenerated schema.md  (6,984 bytes)

# %%
schema = out.read_text(encoding="utf-8")
print(f"{len(schema.splitlines())} lines generated")
print("\n".join(schema.splitlines()[:40]))
# Out:
# 219 lines generated
# # Database schema
#
# > **Generated file — do not edit by hand.**
# > Regenerate by running `notebooks/10_generate_docs.ipynb`.
# > Last generated: 2026-09-06
#
# PostgreSQL 17, reached on host port **5433**. Schema changes are applied through Alembic migrations, never `create_all()`.
#
# ## Entity relationships
#
# ```mermaid
# erDiagram
#     companies ||--o{ documents : has
#     documents ||--o{ elements : has
#     companies ||--o{ facts : has
#     companies ||--o{ prices : has
#     companies {
#         varchar ticker PK
#         varchar name
#         varchar sector
#         varchar yf_symbol
#         varchar financial_currency
#     }
#     documents {
#         varchar document_id PK
#         varchar ticker FK
#         varchar doc_type
#         integer fiscal_year
#         varchar title
#         text source_url
#         varchar sha256
#         text local_path
#         bigint size_bytes
#         integer n_pages
#         timestamptz fetched_at
#     }
#     elements {
#         varchar element_id PK
#         varchar document_id FK
#         integer page
